# %%
from google.colab import drive
import shutil

# %%
# !git clone https://github.com/hirenpatel1404/colab-git-assignment2-hp
# Out:
# fatal: destination path 'colab-git-assignment2-hp' already exists and is not an empty directory.

# %% [markdown]
# # Git and GitHub Assignment 2
# This notebook demonstrates basic Git operations.

# %%
def multiply_numbers(a, b):
    return a * b
print(multiply_numbers(3, 4))
# Out:
# 12

# %% [markdown]
# #Version Control Commands

# %%
#Add and commit the notebook to your repository:
# !git add Assignment 2: Git and GitHub Version Control

# %%
# !ls colab-git-assignment2-hp
# Out:
# assignment2.ipynb

# %%
#Move into the repo folder
# %cd colab-git-assignment2-hp
# Out:
# /content/colab-git-assignment2-hp

# %%
#Set your Git identity
# !git config --global user.email "patels3927@gmail.com"
# !git config --global user.name "hirenpatel1404"

# %%
#add and commit
# !git add assignment2.ipynb
# !git commit -m "Add initial notebook with multiplication function"
# Out:
# On branch main
# Your branch is based on 'origin/main', but the upstream is gone.
#   (use "git branch --unset-upstream" to fixup)
#
# nothing to commit, working tree clean

# %%
#Push to GitHub
# !git push origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
from google.colab import userdata
token = userdata.get('Github_Token')

# !git push https://hirenpatel1404:{token}@github.com/hirenpatel1404/colab-git-assignment2-hp.git main
# Out:
# Enumerating objects: 3, done.
# Counting objects: 100% (3/3), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 1023 bytes | 1023.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/hirenpatel1404/colab-git-assignment2-hp.git
#  * [new branch]      main -> main

# %% [markdown]
# ## Note on Pushing to GitHub
#
# My first push failed with a "could not read Username" error, because
# Colab's `!git` commands can't prompt for a login. Since GitHub no longer
# accepts passwords for pushes, I authenticated with a Personal Access
# Token (PAT). As this is a public repo, I stored the token in Colab
# Secrets instead of pasting it into a cell, then pulled it in at runtime
# so it never appears in my code. The push then succeeded (`main -> main`).

# %%
#Create and switch to a new branch
# !git checkout -b feature-branch
# Out:
# Switched to a new branch 'feature-branch'

# %%
#Add the divide function to your notebook
def divide_numbers(a,b):
  if b != 0:
    return a/b
  else:
    return "Cannot divide by zero"
print (divide_numbers(10,2))
# Out:
# 5.0
